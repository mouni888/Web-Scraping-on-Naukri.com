# %%
import pandas as pd
import  re
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('Naukri.csv')

# %%
df
# Out:
#                                                Job Role  \
# 0                                 Data Analyst || Noida
# 1                                 Business Data Analyst
# 2             EY GDS Data Analyst-Finland based project
# 3       Business Analyst/Data analyst - Payments Domain
# 4                     Data Analyst - Data and Analytics
# ...                                                 ...
# 1495              Sr Data Engineering Analyst - Pentaho
# 1496                   Senior Analyst - Data Processing
# 1497                    Senior Analyst Data Engineering
# 1498           Analyst/Senior Analyst - Data Processing
# 1499  Senior Analyst - AI/RPA, Lending, Big Data and...
#
#                          Company Experience                     Salary  \
# 0                       Conduent    0-3 Yrs              Not disclosed
# 1             NXP Semiconductors    2-5 Yrs              Not disclosed
# 2                             EY    0-1 Yrs              Not disclosed
# ...

# %%
df[["Experience"]].min
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.min of      Experience
# 0       0-3 Yrs
# 1       2-5 Yrs
# 2       0-1 Yrs
# 3       4-8 Yrs
# 4       3-6 Yrs
# ...         ...
# 1495    7-9 Yrs
# 1496    3-8 Yrs
# 1497    5-9 Yrs
# 1498    4-7 Yrs
# 1499    3-5 Yrs
#
# [1500 rows x 1 columns]>

# %%
df[["Experience"]].max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of      Experience
# 0       0-3 Yrs
# 1       2-5 Yrs
# 2       0-1 Yrs
# 3       4-8 Yrs
# 4       3-6 Yrs
# ...         ...
# 1495    7-9 Yrs
# 1496    3-8 Yrs
# 1497    5-9 Yrs
# 1498    4-7 Yrs
# 1499    3-5 Yrs
#
# [1500 rows x 1 columns]>

# %%
k=[]
for i in df["Experience"]:
    if type(i)==float:
        k.append(['0'])
    else:
            k.append(i.split('-'))

# %%
c=pd.DataFrame(k)

# %%
df['MinEx in yrs']=c[0]
df['MaxEx in yrs']=c[1]

# %%
df
# Out:
#                                                Job Role  \
# 0                                 Data Analyst || Noida
# 1                                 Business Data Analyst
# 2             EY GDS Data Analyst-Finland based project
# 3       Business Analyst/Data analyst - Payments Domain
# 4                     Data Analyst - Data and Analytics
# ...                                                 ...
# 1495              Sr Data Engineering Analyst - Pentaho
# 1496                   Senior Analyst - Data Processing
# 1497                    Senior Analyst Data Engineering
# 1498           Analyst/Senior Analyst - Data Processing
# 1499  Senior Analyst - AI/RPA, Lending, Big Data and...
#
#                          Company Experience                     Salary  \
# 0                       Conduent    0-3 Yrs              Not disclosed
# 1             NXP Semiconductors    2-5 Yrs              Not disclosed
# 2                             EY    0-1 Yrs              Not disclosed
# ...

# %%
pip install regex
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\lenovo\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import regex as re
re1=re.compile(r'\d+')
re1.findall(df['MaxEx in yrs'][0])
# Out:
# ['3']

# %%
m=[]
for i in df['MaxEx in yrs']:
    if i is not None:
        m.append(re1.findall(i))
    else:
        m.append(['0'])

# %%
m=pd.Series(m).apply(lambda x:''.join(x))

# %%
df['MaxEx in yrs']=m

# %%
df
# Out:
#                                                Job Role  \
# 0                                 Data Analyst || Noida
# 1                                 Business Data Analyst
# 2             EY GDS Data Analyst-Finland based project
# 3       Business Analyst/Data analyst - Payments Domain
# 4                     Data Analyst - Data and Analytics
# ...                                                 ...
# 1495              Sr Data Engineering Analyst - Pentaho
# 1496                   Senior Analyst - Data Processing
# 1497                    Senior Analyst Data Engineering
# 1498           Analyst/Senior Analyst - Data Processing
# 1499  Senior Analyst - AI/RPA, Lending, Big Data and...
#
#                          Company Experience                     Salary  \
# 0                       Conduent    0-3 Yrs              Not disclosed
# 1             NXP Semiconductors    2-5 Yrs              Not disclosed
# 2                             EY    0-1 Yrs              Not disclosed
# ...

# %%
df[["Salary"]].max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of                          Salary
# 0                 Not disclosed
# 1                 Not disclosed
# 2                 Not disclosed
# 3                 Not disclosed
# 4                 Not disclosed
# ...                         ...
# 1495              Not disclosed
# 1496              Not disclosed
# 1497              Not disclosed
# 1498  15,00,000 - 27,50,000 PA.
# 1499              Not disclosed
#
# [1500 rows x 1 columns]>

# %%
df[["Salary"]].min
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.min of                          Salary
# 0                 Not disclosed
# 1                 Not disclosed
# 2                 Not disclosed
# 3                 Not disclosed
# 4                 Not disclosed
# ...                         ...
# 1495              Not disclosed
# 1496              Not disclosed
# 1497              Not disclosed
# 1498  15,00,000 - 27,50,000 PA.
# 1499              Not disclosed
#
# [1500 rows x 1 columns]>

# %%
k=[]
for i in df["Salary"]:
    k.append(i.split())

# %%
d2=pd.DataFrame(k)

# %%
d2
# Out:
#               0          1          2     3
# 0           Not  disclosed       None  None
# 1           Not  disclosed       None  None
# 2           Not  disclosed       None  None
# 3           Not  disclosed       None  None
# 4           Not  disclosed       None  None
# ...         ...        ...        ...   ...
# 1495        Not  disclosed       None  None
# 1496        Not  disclosed       None  None
# 1497        Not  disclosed       None  None
# 1498  15,00,000          -  27,50,000   PA.
# 1499        Not  disclosed       None  None
#
# [1500 rows x 4 columns]

# %%
Startingsal=d2[0]

# %%
Endingsal=[]
for i in d2[2]:
    if i=='1':
        Endingsal.append("100,000,000")
    else:
        Endingsal.append(i)

# %%
df['Startingsal']=Startingsal
df['Endingsal']=Endingsal

# %%
Startingsal[0]
# Out:
# 'Not'

# %%
df
# Out:
#                                                Job Role  \
# 0                                 Data Analyst || Noida
# 1                                 Business Data Analyst
# 2             EY GDS Data Analyst-Finland based project
# 3       Business Analyst/Data analyst - Payments Domain
# 4                     Data Analyst - Data and Analytics
# ...                                                 ...
# 1495              Sr Data Engineering Analyst - Pentaho
# 1496                   Senior Analyst - Data Processing
# 1497                    Senior Analyst Data Engineering
# 1498           Analyst/Senior Analyst - Data Processing
# 1499  Senior Analyst - AI/RPA, Lending, Big Data and...
#
#                          Company Experience                     Salary  \
# 0                       Conduent    0-3 Yrs              Not disclosed
# 1             NXP Semiconductors    2-5 Yrs              Not disclosed
# 2                             EY    0-1 Yrs              Not disclosed
# ...

# %%
df['Location'].value_counts()
# Out:
# Bangalore/Bengaluru                                                                                    327
# Mumbai                                                                                                 115
# Gurgaon/Gurugram                                                                                       112
# Chennai                                                                                                104
# Hyderabad/Secunderabad                                                                                 103
#                                                                                                       ...
# Ahmedabad, Mumbai (All Areas)                                                                            1
# Navi Mumbai, Juinagar                                                                                    1
# Kolkata, Mumbai, Hyderabad/Secunderabad, Pune, Ahmedabad, Chennai, Delhi / NCR, Bangalore/Bengaluru      1
# ...

# %%
s=[]
for i in df["Location"]:
    s.append(i.split())

# %%
d3=pd.DataFrame(s)

# %%
d3
# Out:
#                            0      1         2                    3     4   \
# 0                       Noida   None      None                 None  None
# 1         Bangalore/Bengaluru   None      None                 None  None
# 2         Bangalore/Bengaluru   None      None                 None  None
# 3     Hyderabad/Secunderabad,  Pune,  Chennai,  Bangalore/Bengaluru  None
# 4         Bangalore/Bengaluru   None      None                 None  None
# ...                       ...    ...       ...                  ...   ...
# 1495   Hyderabad/Secunderabad   None      None                 None  None
# 1496   Hyderabad/Secunderabad   None      None                 None  None
# 1497                    Noida   None      None                 None  None
# 1498                Hyderabad   None      None                 None  None
# 1499                   Mumbai   None      None                 None  None
#
#         5     6     7     8     9     10    11    12
# ...

# %%
import pandas as pd
l=[]
for i in df['Location']:
    if 'h' in i.lower():
        l.append('Hyderabad')
    else:
        l.append(' Not')

# %%
l=pd.Series(l).apply(lambda x:''.join(x))

# %%
df['Location']=l

# %%
df
# Out:
#                                                Job Role  \
# 0                                 Data Analyst || Noida
# 1                                 Business Data Analyst
# 2             EY GDS Data Analyst-Finland based project
# 3       Business Analyst/Data analyst - Payments Domain
# 4                     Data Analyst - Data and Analytics
# ...                                                 ...
# 1495              Sr Data Engineering Analyst - Pentaho
# 1496                   Senior Analyst - Data Processing
# 1497                    Senior Analyst Data Engineering
# 1498           Analyst/Senior Analyst - Data Processing
# 1499  Senior Analyst - AI/RPA, Lending, Big Data and...
#
#                          Company Experience                     Salary  \
# 0                       Conduent    0-3 Yrs              Not disclosed
# 1             NXP Semiconductors    2-5 Yrs              Not disclosed
# 2                             EY    0-1 Yrs              Not disclosed
# ...

# %%
df['Skills'].value_counts()
# Out:
# Data Analyst                                                                                                           8
# Data analysisSASLinuxAnalyticalMachine learningEngineering ManagerWindowsData mining                                   4
# IT SkillsOracleSAPBusiness analysisWorkflowbusiness rulesData AnalystInformatica                                       4
# Computer scienceData analysisOperating systemsData modelingDatabase designDatabaseData structuresBusiness solutions    3
# IT SkillsPythonTestingData ScienceCloudAWSTableauTicketing                                                             3
#                                                                                                                       ..
# MicrostrategyComputer scienceData analysisGoogle AnalyticsWeb analyticsJavascriptOmnitureBusiness intelligence         1
# IT SkillsPythonTestingMachine LearningPDFCodingData AnalystHTTP                                                        1
# ...

# %%
import pandas as pd
j1=[]
for i in df['Skills']:
    if 'p' in i.lower():
        j1.append('Python')
    else:
        j1.append(' Not')

# %%
j1=pd.Series(j1).apply(lambda x:''.join(x))

# %%
df['Skill1']=j1

# %%
df
# Out:
#                                                Job Role  \
# 0                                 Data Analyst || Noida
# 1                                 Business Data Analyst
# 2             EY GDS Data Analyst-Finland based project
# 3       Business Analyst/Data analyst - Payments Domain
# 4                     Data Analyst - Data and Analytics
# ...                                                 ...
# 1495              Sr Data Engineering Analyst - Pentaho
# 1496                   Senior Analyst - Data Processing
# 1497                    Senior Analyst Data Engineering
# 1498           Analyst/Senior Analyst - Data Processing
# 1499  Senior Analyst - AI/RPA, Lending, Big Data and...
#
#                          Company Experience                     Salary  \
# 0                       Conduent    0-3 Yrs              Not disclosed
# 1             NXP Semiconductors    2-5 Yrs              Not disclosed
# 2                             EY    0-1 Yrs              Not disclosed
# ...

# %%
import pandas as pd
j2=[]
for i in df['Skills']:
    if 'i' in i.lower():
        j2.append('IT Skills')
    else:
        j2.append(' Not')

# %%
j2=pd.Series(j2).apply(lambda x:''.join(x))

# %%
df['Skills2']=j2

# %%
df
# Out:
#                                                Job Role  \
# 0                                 Data Analyst || Noida
# 1                                 Business Data Analyst
# 2             EY GDS Data Analyst-Finland based project
# 3       Business Analyst/Data analyst - Payments Domain
# 4                     Data Analyst - Data and Analytics
# ...                                                 ...
# 1495              Sr Data Engineering Analyst - Pentaho
# 1496                   Senior Analyst - Data Processing
# 1497                    Senior Analyst Data Engineering
# 1498           Analyst/Senior Analyst - Data Processing
# 1499  Senior Analyst - AI/RPA, Lending, Big Data and...
#
#                          Company Experience                     Salary  \
# 0                       Conduent    0-3 Yrs              Not disclosed
# 1             NXP Semiconductors    2-5 Yrs              Not disclosed
# 2                             EY    0-1 Yrs              Not disclosed
# ...

# %%
import pandas as pd
j3=[]
for i in df['Skills']:
    if 'a' in i.lower():
        j3.append('Artificial Intelligence ')
    else:
        j3.append(' Not')

# %%
j3=pd.Series(j3).apply(lambda x:''.join(x))

# %%
df['Skills3']=j3

# %%
df
# Out:
#                                                Job Role  \
# 0                                 Data Analyst || Noida
# 1                                 Business Data Analyst
# 2             EY GDS Data Analyst-Finland based project
# 3       Business Analyst/Data analyst - Payments Domain
# 4                     Data Analyst - Data and Analytics
# ...                                                 ...
# 1495              Sr Data Engineering Analyst - Pentaho
# 1496                   Senior Analyst - Data Processing
# 1497                    Senior Analyst Data Engineering
# 1498           Analyst/Senior Analyst - Data Processing
# 1499  Senior Analyst - AI/RPA, Lending, Big Data and...
#
#                          Company Experience                     Salary  \
# 0                       Conduent    0-3 Yrs              Not disclosed
# 1             NXP Semiconductors    2-5 Yrs              Not disclosed
# 2                             EY    0-1 Yrs              Not disclosed
# ...

# %%
import pandas as pd
j4=[]
for i in df['Skills']:
    if 'j' in i.lower():
        j4.append('JavaScript ')
    else:
        j4.append(' Not')

# %%
j4=pd.Series(j4).apply(lambda x:''.join(x))

# %%
df['Skills4']=j4

# %%
df
# Out:
#                                                Job Role  \
# 0                                 Data Analyst || Noida
# 1                                 Business Data Analyst
# 2             EY GDS Data Analyst-Finland based project
# 3       Business Analyst/Data analyst - Payments Domain
# 4                     Data Analyst - Data and Analytics
# ...                                                 ...
# 1495              Sr Data Engineering Analyst - Pentaho
# 1496                   Senior Analyst - Data Processing
# 1497                    Senior Analyst Data Engineering
# 1498           Analyst/Senior Analyst - Data Processing
# 1499  Senior Analyst - AI/RPA, Lending, Big Data and...
#
#                          Company Experience                     Salary  \
# 0                       Conduent    0-3 Yrs              Not disclosed
# 1             NXP Semiconductors    2-5 Yrs              Not disclosed
# 2                             EY    0-1 Yrs              Not disclosed
# ...

# %%
import pandas as pd
j5=[]
for i in df['Skills']:
    if 'h' in i.lower():
        j5.append('HTML ')
    else:
        j5.append(' Not')

# %%
j5=pd.Series(j5).apply(lambda x:''.join(x))

# %%
df['Skills5']=j5

# %%
df
# Out:
#                                                Job Role  \
# 0                                 Data Analyst || Noida
# 1                                 Business Data Analyst
# 2             EY GDS Data Analyst-Finland based project
# 3       Business Analyst/Data analyst - Payments Domain
# 4                     Data Analyst - Data and Analytics
# ...                                                 ...
# 1495              Sr Data Engineering Analyst - Pentaho
# 1496                   Senior Analyst - Data Processing
# 1497                    Senior Analyst Data Engineering
# 1498           Analyst/Senior Analyst - Data Processing
# 1499  Senior Analyst - AI/RPA, Lending, Big Data and...
#
#                          Company Experience                     Salary  \
# 0                       Conduent    0-3 Yrs              Not disclosed
# 1             NXP Semiconductors    2-5 Yrs              Not disclosed
# 2                             EY    0-1 Yrs              Not disclosed
# ...

# %%
import pandas as pd
j6=[]
for i in df['Skills']:
    if 'c' in i.lower():
        j6.append('Communication Skills')
    else:
        j6.append(' Not')

# %%
j6=pd.Series(j6).apply(lambda x:''.join(x))

# %%
df['Skills6']=j6

# %%
df
# Out:
#                                                Job Role  \
# 0                                 Data Analyst || Noida
# 1                                 Business Data Analyst
# 2             EY GDS Data Analyst-Finland based project
# 3       Business Analyst/Data analyst - Payments Domain
# 4                     Data Analyst - Data and Analytics
# ...                                                 ...
# 1495              Sr Data Engineering Analyst - Pentaho
# 1496                   Senior Analyst - Data Processing
# 1497                    Senior Analyst Data Engineering
# 1498           Analyst/Senior Analyst - Data Processing
# 1499  Senior Analyst - AI/RPA, Lending, Big Data and...
#
#                          Company Experience                     Salary  \
# 0                       Conduent    0-3 Yrs              Not disclosed
# 1             NXP Semiconductors    2-5 Yrs              Not disclosed
# 2                             EY    0-1 Yrs              Not disclosed
# ...

# %%
df.drop(columns=['Experience','Salary','Skills'],inplace=True)

# %%
df
# Out:
#                                                Job Role  \
# 0                                 Data Analyst || Noida
# 1                                 Business Data Analyst
# 2             EY GDS Data Analyst-Finland based project
# 3       Business Analyst/Data analyst - Payments Domain
# 4                     Data Analyst - Data and Analytics
# ...                                                 ...
# 1495              Sr Data Engineering Analyst - Pentaho
# 1496                   Senior Analyst - Data Processing
# 1497                    Senior Analyst Data Engineering
# 1498           Analyst/Senior Analyst - Data Processing
# 1499  Senior Analyst - AI/RPA, Lending, Big Data and...
#
#                          Company   Location MinEx in yrs MaxEx in yrs  \
# 0                       Conduent        Not            0            3
# 1             NXP Semiconductors        Not            2            5
# 2                             EY        Not            0            1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Job Role      1500 non-null   object
#  1   Company       1500 non-null   object
#  2   Location      1500 non-null   object
#  3   MinEx in yrs  1500 non-null   object
#  4   MaxEx in yrs  1500 non-null   object
#  5   Startingsal   1500 non-null   object
#  6   Endingsal     150 non-null    object
#  7   Skill1        1500 non-null   object
#  8   Skills2       1500 non-null   object
#  9   Skills3       1500 non-null   object
#  10  Skills4       1500 non-null   object
#  11  Skills5       1500 non-null   object
#  12  Skills6       1500 non-null   object
# dtypes: object(13)
# memory usage: 152.5+ KB

# %%
df['MinEx in yrs'].fillna(df['MinEx in yrs'] .mean())
# Out:
# 0       0
# 1       2
# 2       0
# 3       4
# 4       3
#        ..
# 1495    7
# 1496    3
# 1497    5
# 1498    4
# 1499    3
# Name: MinEx in yrs, Length: 1500, dtype: object

# %%
df['MaxEx in yrs'].fillna(df['MaxEx in yrs'] .mean())
# Out:
# 0       3
# 1       5
# 2       1
# 3       8
# 4       6
#        ..
# 1495    9
# 1496    8
# 1497    9
# 1498    7
# 1499    5
# Name: MaxEx in yrs, Length: 1500, dtype: object

# %%
df['MaxEx in yrs'].value_counts()
# Out:
# 5     286
# 6     207
# 7     195
# 8     161
# 3     151
# 4     144
# 10    109
# 9      77
# 2      62
# 1      28
# 12     26
# 11     17
# 13     16
# 0       9
# 15      5
# 14      4
# 18      2
# 20      1
# Name: MaxEx in yrs, dtype: int64

# %%
df['MinEx in yrs'].value_counts()
# Out:
# 2     380
# 3     318
# 1     265
# 5     164
# 4     163
# 0     105
# 6      34
# 7      32
# 8      23
# 10     10
# 9       4
# 15      2
# Name: MinEx in yrs, dtype: int64

# %%
df['Startingsal'] = df['Startingsal'].fillna(0) #replacing the nan values to 0

# %%
df
# Out:
#                                                Job Role  \
# 0                                 Data Analyst || Noida
# 1                                 Business Data Analyst
# 2             EY GDS Data Analyst-Finland based project
# 3       Business Analyst/Data analyst - Payments Domain
# 4                     Data Analyst - Data and Analytics
# ...                                                 ...
# 1495              Sr Data Engineering Analyst - Pentaho
# 1496                   Senior Analyst - Data Processing
# 1497                    Senior Analyst Data Engineering
# 1498           Analyst/Senior Analyst - Data Processing
# 1499  Senior Analyst - AI/RPA, Lending, Big Data and...
#
#                          Company   Location MinEx in yrs MaxEx in yrs  \
# 0                       Conduent        Not            0            3
# 1             NXP Semiconductors        Not            2            5
# 2                             EY        Not            0            1
# ...

# %%
df['Endingsal'] = df['Endingsal'].fillna(0) #replacing the nan values to 0

# %%
df
# Out:
#                                                Job Role  \
# 0                                 Data Analyst || Noida
# 1                                 Business Data Analyst
# 2             EY GDS Data Analyst-Finland based project
# 3       Business Analyst/Data analyst - Payments Domain
# 4                     Data Analyst - Data and Analytics
# ...                                                 ...
# 1495              Sr Data Engineering Analyst - Pentaho
# 1496                   Senior Analyst - Data Processing
# 1497                    Senior Analyst Data Engineering
# 1498           Analyst/Senior Analyst - Data Processing
# 1499  Senior Analyst - AI/RPA, Lending, Big Data and...
#
#                          Company   Location MinEx in yrs MaxEx in yrs  \
# 0                       Conduent        Not            0            3
# 1             NXP Semiconductors        Not            2            5
# 2                             EY        Not            0            1
# ...

# %%
df['Location']=df['Location'].apply(lambda x : 'Hyderabad/Secundrabad' if 'Not' in str(x) else str(x))

# %%
df
# Out:
#                                                Job Role  \
# 0                                 Data Analyst || Noida
# 1                                 Business Data Analyst
# 2             EY GDS Data Analyst-Finland based project
# 3       Business Analyst/Data analyst - Payments Domain
# 4                     Data Analyst - Data and Analytics
# ...                                                 ...
# 1495              Sr Data Engineering Analyst - Pentaho
# 1496                   Senior Analyst - Data Processing
# 1497                    Senior Analyst Data Engineering
# 1498           Analyst/Senior Analyst - Data Processing
# 1499  Senior Analyst - AI/RPA, Lending, Big Data and...
#
#                          Company               Location MinEx in yrs  \
# 0                       Conduent  Hyderabad/Secundrabad            0
# 1             NXP Semiconductors  Hyderabad/Secundrabad            2
# 2                             EY  Hyderabad/Secundrabad            0
# ...

# %%
df.to_csv('Naukri_visual.csv',index=False)

# %%
df
# Out:
#                                                Job Role  \
# 0                                 Data Analyst || Noida
# 1                                 Business Data Analyst
# 2             EY GDS Data Analyst-Finland based project
# 3       Business Analyst/Data analyst - Payments Domain
# 4                     Data Analyst - Data and Analytics
# ...                                                 ...
# 1495              Sr Data Engineering Analyst - Pentaho
# 1496                   Senior Analyst - Data Processing
# 1497                    Senior Analyst Data Engineering
# 1498           Analyst/Senior Analyst - Data Processing
# 1499  Senior Analyst - AI/RPA, Lending, Big Data and...
#
#                          Company               Location MinEx in yrs  \
# 0                       Conduent  Hyderabad/Secundrabad            0
# 1             NXP Semiconductors  Hyderabad/Secundrabad            2
# 2                             EY  Hyderabad/Secundrabad            0
# ...

# %% [markdown]
# ### DATA Visualization

# %% [markdown]
# ### Univariate

# %%
import  re
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_naukri = pd.read_csv('Naukri_visual.csv')

# %%
df_naukri
# Out:
#                                                Job Role  \
# 0                                 Data Analyst || Noida
# 1                                 Business Data Analyst
# 2             EY GDS Data Analyst-Finland based project
# 3       Business Analyst/Data analyst - Payments Domain
# 4                     Data Analyst - Data and Analytics
# ...                                                 ...
# 1495              Sr Data Engineering Analyst - Pentaho
# 1496                   Senior Analyst - Data Processing
# 1497                    Senior Analyst Data Engineering
# 1498           Analyst/Senior Analyst - Data Processing
# 1499  Senior Analyst - AI/RPA, Lending, Big Data and...
#
#                          Company               Location  MinEx in yrs  \
# 0                       Conduent  Hyderabad/Secundrabad             0
# 1             NXP Semiconductors  Hyderabad/Secundrabad             2
# 2                             EY  Hyderabad/Secundrabad             0
# ...

# %% [markdown]
# ### Countplot

# %%
df_naukri["Job Role"].value_counts().nlargest(10).plot.bar()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,6))
sns.barplot(hue= 'Company',y = 'MinEx in yrs',x='Location',data=df_naukri["Company"]
# Out:
#   Input In [97]
#     sns.barplot(hue= 'Company',y = 'MinEx in yrs',x='Location',data=df_naukri["Company"]
#                                                                                         ^
# SyntaxError: incomplete input

# %% [markdown]
# ### Piechart

# %%
df1_naukri["Company"].value_counts().plot.pie(autopct="%.2f%%");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [94], in <cell line: 1>()
# ----> 1 df1_naukri["Company"].value_counts().plot.pie(autopct="%.2f%%")
#
# NameError: name 'df1_naukri' is not defined

# %%
a =pd.DataFrame(df1_naukri["Company"].value_counts())
a

# %%
plt.pie(a["Company"], labels = a.index, autopct='%.0f%%')
plt.show()

# %%
a =pd.DataFrame(df1_naukri["Job Role"].value_counts())
a

# %%
plt.pie(a["Job Role"], labels = a.index, autopct='%.0f%%')
plt.show()

# %%
a =pd.DataFrame(df_naukri["JobType"].value_counts())
a

# %%
plt.pie(a["JobType"], labels = a.index, autopct='%.0f%%')
plt.show()

# %% [markdown]
# https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
colors = sns.color_palette('pastel')[0:5]
plt.pie(a["JobType"], labels = a.index,colors=colors, autopct='%.0f%%')
plt.show()

# %% [markdown]
# ### Numerical data

# %%
df1_naukri.columns

# %%
sns.countplot(x='Rating', data=df_naukri)

# %% [markdown]
# ### Histograms

# %%
df_naukri["Rating"].hist()

# %%
help(sns.distplot)

# %%
sns.distplot(df_naukri["Rating"],kde=False,bins = [2,3,6,8])
plt.title('Histogram of Rating')
plt.show()

# %%
sns.distplot(df_naukri["Rating"],kde=False)
plt.title('Histogram of Rating')
plt.show()

# %%
sns.distplot(df_naukri["Rating"],kde=True)
plt.title('Histogram of Rating')
plt.show()

# %% [markdown]
# ### Boxplot
